# %% [markdown]
# # **Density-based spatial clustering (DBSCAN)**
#
# DBSCAN documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html)

# %%
import numpy as np
from matplotlib import pyplot as plt

from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
X, y = make_blobs(n_samples = 500, n_features = 2, random_state=10)

# Train test splits
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

_, axes = plt.subplots(1,2, figsize = (8,4))
axes[0].scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap="Paired")
axes[1].scatter(X_train[:, 0], X_train[:, 1], c='r', edgecolors='k')
axes[1].scatter(X_test[:, 0], X_test[:, 1], c='b', edgecolors='k')
plt.show()

# %%
dbscan = DBSCAN(eps= 1 , min_samples= 2 )

# Train DBSCAN
dbscan.fit(X_train)
# Out:
# DBSCAN(eps=1, min_samples=2)

# %%
# Predictions
predictions = dbscan.labels_

# n_clusters = len(set(predictions)) - (1 if -1 in predictions else 0)
n_clusters = np.unique(predictions)

print ("Num clusters {0}".format(len(n_clusters)))
print ("Clusters ID: {0}".format(n_clusters))
print ("Prediction size {0}".format(len(predictions)))
# Out:
# Num clusters 4
# Clusters ID: [-1  0  1  2]
# Prediction size 400

# %%
_, axes = plt.subplots(1,2,figsize = (8,4))
axes[0].scatter(X_train[:,0], X_train[:,1], c=y_train, edgecolors='k', cmap="Paired")
axes[1].scatter(X_train[:,0], X_train[:,1], c=predictions, edgecolors='k', cmap='Paired')

# %% [markdown]
# # **DBSCAN on real data**
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
_


plt.scatter( _ , _ )
print (X.shape, y.shape)

# %%
dbscan = DBSCAN(eps= _ , min_samples= _ )
dbscan.fit( _ )

# %%
predictions = _

# %%
# Plot
_

# %% [markdown]
# # **DBSCAN on images**
#
# Use any of the following images:
#  - [image1.jpeg](https://drive.google.com/file/d/1ehjQbNbSLTPOdnzZf5mtcokH-Irb9Hsq/view?usp=sharing)
#  - [image2.png](https://drive.google.com/file/d/1RxivIbgi2eAG6p1myuxQGJs2zhGEsH_4/view?usp=sharing)
#  - [image3.jpg](https://drive.google.com/file/d/1Pc_C9B_vqIxkLFV90RWSlRxRcTN-yKqF/view?usp=sharing)

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN
from PIL import Image
import cv2

# %%
image = Image.open("/content/image3.jpg")
image = image.resize((365,220))
image = np.array(image)

plt.imshow(image)
print (image.shape)
# Out:
# (220, 365, 3)

# %%
image_hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

vectorized_rgb = image.copy().reshape(-1, 3)
vectorized_hsv = image_hsv.copy()[:,:,0].reshape(-1,1)

print (vectorized_rgb.shape, vectorized_hsv.shape)
# Out:
# (80300, 3) (80300, 1)

# %% [markdown]
# ##**RGB image**

# %%
dbscan = DBSCAN(eps= 10 , min_samples = 9*9)
dbscan.fit(vectorized_rgb)
# Out:
# DBSCAN(eps=10, min_samples=81)

# %%
clustered_rgb = dbscan.labels_
clustered_rgb = clustered_rgb.reshape(image.shape[:2])

print (image.shape, clustered_rgb.shape)
# Out:
# (220, 365, 3) (220, 365)

# %%
_, axes = plt.subplots(1,2,figsize=(8,4))
axes[0].imshow(image), axes[0].set_title("Original image")
axes[1].imshow(clustered_rgb, cmap='Paired'), axes[1].set_title("Segmented image")
for ax in axes: ax.set_axis_off()

# %% [markdown]
# ##**HSV image**

# %%
dbscan = DBSCAN(eps= 5 , min_samples = 5*5)
dbscan.fit(vectorized_hsv)

# %%
clustered_rgb = dbscan.labels_
clustered_rgb = clustered_rgb.reshape(image.shape[:2])

print (image.shape, clustered_rgb.shape)

# %%
_, axes = plt.subplots(1,2,figsize=(8,4))
axes[0].imshow(image), axes[0].set_title("Original image")
axes[1].imshow(clustered_rgb, cmap='Paired'), axes[1].set_title("Segmented image")
for ax in axes: ax.set_axis_off()
