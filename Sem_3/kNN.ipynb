# %% [markdown]
# # **k - Nearest Neighbors**

# %% [markdown]
# Iris dataset [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris) \
# k-NN documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier as kNN
from sklearn.datasets import load_iris # Iris dataset

# %%
iris = load_iris() # Load the iris dataset
iris_x = iris.data[:, 0:2] # Features. We'll pick 2
iris_y = iris.target # Labels
iris_names = iris.target_names # Name of classes
iris_features = iris.feature_names

# Print shapes
print ( iris_x.shape, iris_y.shape, '\n', iris_names, '\n', iris_features)
# Out:
# (150, 2) (150,)
#  ['setosa' 'versicolor' 'virginica']
#  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
_, ax = plt.subplots (figsize=(6,5))
ax.scatter(iris_x[:,0], iris_x[:,1], c=iris_y, edgecolors='k', cmap="Paired")
ax.set_xlabel(iris_features[0])
ax.set_ylabel(iris_features[1])
ax.set_xticks([]), ax.set_yticks([])
# Out:
# ([], [])

# %%
# Instance kNN object
n_neighbors = 5
knn = kNN(n_neighbors = n_neighbors , metric = "euclidean")

# Training
knn.fit( iris_x , iris_y ) # (num_samples, num_features), (num_samples)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Docencia/Aprendizaje/2023-2/J10/
# !ls
# Out:
# /content/drive/MyDrive/Docencia/Aprendizaje/2023-2/J10
# Images	README.md  repo  Sem_1	Sem_2  Sem_3  Sem_4  Sem_5  Sem_6  Sem_9  Tools

# %%
import sys
# print (sys.path)
# sys.path.append("/content/drive/MyDrive/Docencia/Aprendizaje/2023-2/J10/")
sys.path.append("../")
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython', '../']

# %%
from Tools.utils import plot_decision_boundary

# %%
## Plot decision boundaries
plot_decision_boundary(knn, iris_x, iris_y, res=0.01)

# %%
h_min, h_max = iris_x[:,0].min()-0.1, iris_x[:,0].max()+0.1
v_min, v_max = iris_x[:,1].min()-0.1, iris_x[:,1].max()+0.1

h_grid, v_grid = np.meshgrid(np.arange(h_min, h_max, 0.01), np.arange(v_min, v_max, 0.01))

predictions = np.c_[h_grid.ravel(), v_grid.ravel()]
predictions = knn.predict(predictions)
predictions = predictions.reshape(h_grid.shape)

# %%
print(h_grid.shape, v_grid.shape, predictions.shape)
# Out:
# (260, 380) (260, 380) (260, 380)

# %%
_, ax = plt.subplots(figsize=(7,6))

ax.pcolormesh(h_grid, v_grid, predictions, cmap="Paired")
ax.contour(h_grid, v_grid, predictions, colors=['k','k','k'], linestyles='--', levels=[-1,0,1])
ax.scatter (iris_x[:, 0], iris_x[:,1], c=iris_y, edgecolors='k', cmap="Paired")

ax.set_xlabel(iris_features[0])
ax.set_ylabel(iris_features[1])

ax.set_xticks([]), ax.set_yticks([])
# Out:
# ([], [])

# %% [markdown]
# ## Using the Fruits dataset
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier as kNN
from sklearn.datasets import load_iris # Iris dataset

# %%
fruit_data = _ # Load the fruits dataset
fruits_x = _  # Features. We'll pick 2
fruits_y = _  # Labels

# Convert everything to a np array
fruits_x, fruits_y = np.asarray(fruits_x), np.asarray(fruits_y)

# Print shapes
print ( _ )

# %%
# Instance kNN object
n_neighbors = _
knn = kNN(n_neighbors = _ )

# Training
 _ #(num_samples, Features)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
## Plot decision boundaries
_
